# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\rrama\OneDrive\Desktop\Python code\mckinsey.csv")

# %%
df

# %%
df.head(3)

# %%
type(df)

# %%
df ["country"]

# %%
df.info()

# %%
df.head()

# %%
df.tail(20)

# %%
df.shape

# %%
df.tail(15)

# %%
pd.DataFrame([['Afghanistan',1952, 8425333, 'Asia', 28.801, 779.445314 ],
 ['Afghanistan',1957, 9240934, 'Asia', 30.332, 820.853030 ],
 ['Afghanistan',1962, 102267083, 'Asia', 31.997, 853.100710 ]],
 columns=['country','year','population','continent','life_exp','gdp_cap'])

# %%
pd.DataFrame([['Afghanistan',1952, 8425333, 'Asia', 28.801, 779.445314 ]],
 columns=['country','year','population','continent','life_exp','gdp_cap'])

# %%
pd.DataFrame({'country':['Afghanistan', 'Afghanistan'], 'year':[1952,1957],
 'population':[842533, 9240934], 'continent':['Asia', 'Asia'],
 'life_exp':[28.801, 30.332], 'gdp_cap':[779.44, 820.853030]})

# %%
df.columns

# %%
df.keys

# %%
df['country'].head()

# %%
df[['country','year']].head()

# %%
df['country'].unique()

# %%
df['country'].value_counts()

# %%
type(df)

# %%
df.rename({"population":"population" ,"country":"country"} ,axis =1)

# %%
df.rename(columns={"country":"Country"})

# %%
df.rename({"country":"Country"} ,axis=1 ,inplace = True)
df

# %%
df.Country

# %%
df.drop('continent',axis=1)

# %%
df.drop(columns=['continent'])

# %%
df.head()

# %%
df.drop(columns=['continent'])

# %%
df.drop('continent',axis=1)

# %%
df.head()

# %%
df.drop('continent',axis=1)

# %%
df.drop("continent",axis =1,inplace=True)

# %%
df.head()

# %%
df["year+7"] = df["year"] +7
df.head()

# %%
df["gdp"] =df["gdp_cap"]*df["population"]
df.head()

# %%
df["own"]=[i for i in range(1704)]
df

# %%
df.drop(columns=["own",'gdp', 'year+7'], axis = 1, inplace = True)
df

# %%
df.index.values

# %%
df.index = list(range(1, df.shape[0]+1))
df

# %%
df.index[1]

# %%
df.index = np.arange(1, df.shape[0]+1, dtype='float')
df

# %%
df.head()

# %%
df.drop(columns=['life_exp', 'year'], axis = 1, inplace = True)
df

# %%
df = pd.read_csv(r"C:\Users\rrama\OneDrive\Desktop\Python code\groupby_practice_dataset.csv")

# %%
df

# %%
df.groupby(['product_category'])['total_amount'].sum()

# %%
df.groupby(['product_category']) ['unit_price'].mean()

# %%
df.groupby(['customer_city'])['quantity'].sum()

# %%
df.groupby(['payment_method'])['order_id'].count()

# %%
df.groupby(['customer_city'])['total_amount'].max()

# %%
df.groupby(['customer_city','product_category'])['total_amount'].sum()

# %%
df.groupby(['customer_id'])['total_amount'].mean()

# %%
df.groupby(['order_date'])['total_amount'].sum()

# %%
df.groupby(['customer_city'])['total_amount'].sum().nlargest(3)

# %%
df.groupby(['payment_method']).agg(total_sales=('total_amount','sum'),total_orders=('order_id','count'))

# %%
sales=df.groupby(['product_category','customer_city'])['total_amount'].sum().reset_index()

# %%
result = sales.loc[
    sales.groupby('product_category')['total_amount'].idxmax()
]

# %%
print(sales)

# %%
df.groupby(['product_category','customer_city'])['total_amount'].sum() \
  .reset_index() \
  .loc[lambda x: x.groupby('product_category')['total_amount'].idxmax()]

# %%
df.groupby(['product_category','customer_city'])['total_amount'].max()

# %%
# !pip install openpyxl

# %%
import pandas as pd
file_path =r"C:\Users\rrama\OneDrive\Desktop\Python code\ACCOUNT_PERF_DATA (1).xlsx"
med_2026=pd.read_excel(file_path,sheet_name='ACCOUNT_PERFORMANCE_DATA')
med_2026

# %%
salary=[1000,3000,5000,7000,3000,4000,80000]

# %%
salary

# %%
unique=list(set(salary))

# %%
unique.sort(reverse=True)

# %%
second_highest=unique[1]
print(second_highest)

# %%
med_2026.head(100)

# %%
med_2026.tail(100)

# %%
med_2026[100:]

# %%
med_2026[100:200]

# %% [markdown]
# # HOW TO CREATE A NEW DATASET FROM AN EXSITING DATASET

# %%
med_2026_v1=med_2026
med_2026_v1

# %%
med_2026_v1=med_2026.copy()
med_2026_v1

# %% [markdown]
# # HOW  TO DESCRIBE  YOU DATASET

# %%
med_2026.info
# all set of record in the dataset

# %%
med_2026.columns.values
# lists of header in the dataset

# %%
med_2026.count()
# count of record in  each variable

# %%
med_2026.describe()
# give you the statistics for all numeric variables

# %%
med_2026.info()
# it will give the variables data types and count of records in each

# %%
med_2026.isnull().sum()
# it gives each variables wise count  of missing values

# %%
med_2026.isnull().sum().sum()
# this gives each overall missing counts in the dataset

# %% [markdown]
# HOW TO CREATE  A NEW DATASET FROM AN EXSTING DATASET BY SELECTING VARIABLES AND DROPPING VARIABLES

# %%
med_2026.columns.values

# %%
med_2026_v1=med_2026[['Account_number','PORTFOLIO','SSN','County','State']]

# %%
med_2026_v1

# %%
list_vars=['Account_number','PORTFOLIO','SSN','County','State']
med_2026_v2=med_2026[list_vars]
med_2026_v2

# %%
# how to create a new dataset by selecting number of observations
list_vars=['Account_number','PORTFOLIO','SSN','County','State']
med_2026_v3=med_2026[list_vars][0:100]
med_2026_v3

# %%
# how  to create a new dataset by dropping variables
med_2026.columns.values

# %%
med_2026_v4=med_2026.drop(['City','Zip','Last_payment_date','Origination_fico_score', 'Current_fico_score','Current_outstanding'],axis=1)
med_2026_v4

# %%
med_2026_v4.columns.value_counts()

# %%
med_2026_v4.columns.size

# %%
drop_list_values=['City','Zip','Last_payment_date','Origination_fico_score', 'Current_fico_score','Current_outstanding']
med_2026_v4=med_2026.drop(drop_list_values,axis=1)
med_2026_v4

# %% [markdown]
# # HOW TO RETRIVE DATA BY GIVEN CRITERIAS FOR FILTERING

# %%
# WE CAN FILTER DATA USING OPERATORS AND OPERANDS

# THERE ARE 4 TYPES OF OPERATORS
# LOGICAL OPERATOR (AND,OR,IN,NOT,IN)
# COMPARISON OPERATOR (=,>,<,>=,<=,<>)
# SPECIAL OPERATOR(LIKE,BETWEEN,AND)
# ARITHEMATIC OPERATOR(+,-,/,//,%)

# %%
# THERE ARE 4 TYPES OF OPERATORS
list_vars=['Account_number','PORTFOLIO','SSN','County','State']
med_2026_v5=med_2026[list_vars][med_2026['PORTFOLIO']=='PERSONAL LOAN']
med_2026_v5

# %%
list_vars=['Account_number','PORTFOLIO','SSN','County','State']
med_2026_v5=med_2026[list_vars][(med_2026['PORTFOLIO']=='PERSONAL LOAN') & (med_2026['County']=='Cooper')]
med_2026_v5

# %%
list_vars=['Account_number','PORTFOLIO','SSN','County','State']
med_2026_v5=med_2026[list_vars][med_2026['PORTFOLIO']!='PERSONAL LOAN']
med_2026_v5

# %%
list_vars=['Account_number','PORTFOLIO','SSN','County','State']
med_2026_v5=med_2026[list_vars][med_2026['PORTFOLIO'] .isin (['PERSONAL LOAN','CREDIT CARD','MORTGAGE'])]
med_2026_v5

# %%
exclude = ['PERSONAL LOAN', 'CREDIT CARD']

filtered_df = med_2026.loc[
    ~med_2026['PORTFOLIO'].isin(exclude)
]

filtered_df

# %%
print(cid)

# %%
filtered_df['PORTFOLIO'].value_counts()

# %%
med_2026

# %%
med_2026['PORTFOLIO'].value_counts

# %%
list_vars=['Account_number','PORTFOLIO','SSN','County','State','Zip']	
med_2026_v5=med_2026[list_vars][(med_2026['PORTFOLIO']=='PERSONAL LOAN') | (med_2026['County']=='Cooper')]
med_2026_v5

# %%
# COMPARISON OPERATOR (=,>,<,>=,<=,<>)

list_vars=['Account_number','PORTFOLIO','SSN','County','State','Zip']	
med_2026_v5=med_2026[list_vars][med_2026['Zip']>=50000]
med_2026_v5

# %%
# SPECIAL OPERATOR(LIKE,BETWEEN,AND)

list_vars=['Account_number','PORTFOLIO','SSN','County','State','Zip']	
med_2026_v5=med_2026[list_vars][med_2026['County'].str.startswith('L',na=False)]
med_2026_v5

# %%
list_vars=['Account_number','PORTFOLIO','SSN','County','State','Zip']	
med_2026_v5=med_2026[list_vars][med_2026['County'].str.endswith('e',na=False)]
med_2026_v5

# %%
list_vars=['Account_number','PORTFOLIO','SSN','County','State','Zip']	
med_2026_v5=med_2026[list_vars][med_2026['County'].str.contains('e',na=False)]
med_2026_v5

# %%
list_vars=['Account_number','PORTFOLIO','SSN','County','State','Zip']	
age_fliter=med_2026['Zip'].between(7000,30000,inclusive='both')
med_2026_v5=med_2026[list_vars][age_fliter]
med_2026

# %%
list_vars=['Account_number','PORTFOLIO','SSN','County','State','Zip','Origination_fico_score','Current_fico_score']	
med_2026_v5=med_2026[list_vars]
med_2026_v5['new_column']=med_2026_v5['Current_fico_score'] / med_2026_v5['Origination_fico_score']
med_2026_v5

# %%
list_vars=['Account_number','PORTFOLIO','SSN','County','State','Zip','Origination_fico_score','Current_fico_score']	
med_2026_v5=med_2026[list_vars]
med_2026_v5['new_column']=(med_2026_v5['Current_fico_score'] / med_2026_v5['Origination_fico_score']).apply(lambda x: f"${x:,.2f}")
med_2026_v5

# %%
list_vars=['Account_number','PORTFOLIO','SSN','County','State','Zip','Origination_fico_score','Current_fico_score']	
med_2026_v5=med_2026[list_vars]
med_2026_v5['new_column']=(med_2026_v5['Current_fico_score'] / med_2026_v5['Origination_fico_score']).apply(lambda x: f"${x:,.1f}")
med_2026_v5

# %%
list_vars=['Account_number','PORTFOLIO','SSN','County','State','Zip','Origination_fico_score','Current_fico_score']	
med_2026_v5=med_2026[list_vars]
med_2026_v5['new_column']=(med_2026_v5['Current_fico_score'] / med_2026_v5['Origination_fico_score']).apply(lambda x: f"${x:,.0f}")
med_2026_v5

# %% [markdown]
# SORTING DATASET BY VARIABLES

# %%
import pandas as pd
file_name=r"C:\Users\rrama\OneDrive\Desktop\Python code\student_marks_from_image.xlsx"
stu_score=pd.read_excel(file_path)
stu_score

# %%
# lets sort the dataset by stu_name
stu_score_v1=stu_score.sort_values(by=['STU_NAME'])
stu_score

# %%
stu_score_v1=stu_score.sort_values(by=['STU_NAME','SUBJECT','MARKS'])
stu_score

# %%
stu_score_v1=stu_score.sort_values(by=['STU_NAME','YEAR','MARKS'],ascending=[True,True,False])
stu_score_v1

# %%
stu_score_v1.to_excel(r'C:\Users\rrama\OneDrive\Desktop\Python code\stu_score_v1.xlsx',index=False)

# %%
stu_score_v1=stu_score.sort_values(by=['SUBJECT','YEAR','MARKS'],ascending=[True,True,False])
stu_score_v1

# %% [markdown]
# # Summarizing Data

# %%
med_2026.info()

# %%
med_2026.count()

# %%
med_2026['Account_number'].count()

# %%
med_2026.groupby('PORTFOLIO')['Account_number'].count()

# %%
med_2026.groupby('PORTFOLIO')['Account_number'].max()

# %%
med_2026.groupby('PORTFOLIO')['Account_number'].min()

# %%
# how to summarize data using more than one categorical field
med_summary=med_2026['Origination_fico_score'].groupby([med_2026['County'],med_2026['City']]).sum()
med_summary

# %%
med_summary=med_2026['Origination_fico_score'].groupby([med_2026['County'],med_2026['City']]).count()
med_summary

# %%
med_summary=med_2026.groupby(['PORTFOLIO'],as_index=False).agg({'Zip':'count','Origination_fico_score':'sum','Current_fico_score':'mean'})
med_summary=med_summary.rename(columns={'Zip':'count_Zip','Origination_fico_score':'Sum_Origination_fico_score','Current_fico_score':'mean_Current_fico_score'})
med_summary

# %% [markdown]
# USE OF ELSE IF CONDITION

# %%
list_vars=['Account_number','PORTFOLIO','SSN','County','State','Zip']	
med_2026_v5=med_2026[list_vars]
med_2026_v5=med_2026_v5.rename(columns={'Zip':'Zip_no'})
med_2026_v5

# %%
import numpy as np

# %%
# if then with one condition variable
import pandas as pd
import numpy as np
med_2026_v5['New_Zip']=np.where(med_2026_v5['Zip_no']>60000,'primier','non primier')
med_2026_v5

# %%
med_2026_v5['Discount']=[i*.20 if i<5000 else i*.10 if i < 9000 else i*.05 for i in med_2026_v5.Zip_no]
med_2026_v5

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\rrama\OneDrive\Desktop\Python code\pandas_practice_dataset.csv")
df
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 1        1002           29  North          Grocery   2241  2599      15.0
# 2        1003           15   West      Electronics   3159  1274       NaN
# 3        1004           43  South          Grocery   4648   978       5.0
# 4        1005            8  South        Furniture   3059  2086       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 195      1196           37   East         Clothing    639   932       0.0
# 196      1197           33  South      Electronics   2879  1080       0.0
# 197      1198           42  North      Electronics   4236  1076      15.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit
# 0    2024-01-01     3109    1113
# 1    2024-01-02     2164    -435
# 2    2024-01-03     3017    1743
# 3    2024-01-04     4519    3541
# 4    2024-01-05     3013     927
# ..          ...      ...     ...
# 195  2024-07-14      621    -311
# 196  2024-07-15     2830    1750
# 197  2024-07-16     4202    3126
# 198  2024-07-17     4823    3127
# 199  2024-07-18     3844    2876
#
# [200 rows x 10 columns]

# %%
# Display first 10 rows of the dataset.
df.head(10)
# Out:
#    order_id  customer_id region product_category  sales  cost  discount  \
# 0      1001           39  North      Electronics   3218  1996      10.0
# 1      1002           29  North          Grocery   2241  2599      15.0
# 2      1003           15   West      Electronics   3159  1274       NaN
# 3      1004           43  South          Grocery   4648   978       5.0
# 4      1005            8  South        Furniture   3059  2086       5.0
# 5      1006           21  South          Grocery   2365  2558      10.0
# 6      1007           39   East        Furniture   2579  2829      10.0
# 7      1008           19  South          Grocery   4746  2849       0.0
# 8      1009           23   East      Electronics   1735   974       NaN
# 9      1010           11   West          Grocery   1857  1631      15.0
#
#    order_date  revenue  profit
# 0  2024-01-01     3109    1113
# 1  2024-01-02     2164    -435
# 2  2024-01-03     3017    1743
# 3  2024-01-04     4519    3541
# 4  2024-01-05     3013     927
# 5  2024-01-06     2284    -274
# 6  2024-01-07     2443    -386
# 7  2024-01-08     4631    1782
# 8  2024-01-09     1634     660
# 9  2024-01-10     1817     186

# %%
# Display last 5 rows.
df.tail(5)
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 195      1196           37   East         Clothing    639   932       0.0
# 196      1197           33  South      Electronics   2879  1080       0.0
# 197      1198           42  North      Electronics   4236  1076      15.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit
# 195  2024-07-14      621    -311
# 196  2024-07-15     2830    1750
# 197  2024-07-16     4202    3126
# 198  2024-07-17     4823    3127
# 199  2024-07-18     3844    2876

# %%
# Show column names of the dataset.
df.columns.values
# Out:
# array(['order_id', 'customer_id', 'region', 'product_category', 'sales',
#        'cost', 'discount', 'order_date', 'revenue', 'profit'],
#       dtype=object)

# %%
# Check data types of each column.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          200 non-null    int64
#  1   customer_id       200 non-null    int64
#  2   region            200 non-null    object
#  3   product_category  200 non-null    object
#  4   sales             200 non-null    int64
#  5   cost              200 non-null    int64
#  6   discount          160 non-null    float64
#  7   order_date        200 non-null    object
#  8   revenue           200 non-null    int64
#  9   profit            200 non-null    int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 15.8+ KB

# %%
# Find total number of missing values per column.
df.isnull().sum()
# Out:
# order_id             0
# customer_id          0
# region               0
# product_category     0
# sales                0
# cost                 0
# discount            40
# order_date           0
# revenue              0
# profit               0
# dtype: int64

# %%
# Select only the column sales.
df [["sales"]]
# Out:
#      sales
# 0     3218
# 1     2241
# 2     3159
# 3     4648
# 4     3059
# ..     ...
# 195    639
# 196   2879
# 197   4236
# 198   4935
# 199   3875
#
# [200 rows x 1 columns]

# %%
# Select columns customer_id and region.
df [["customer_id","region"]]
# Out:
#      customer_id region
# 0             39  North
# 1             29  North
# 2             15   West
# 3             43  South
# 4              8  South
# ..           ...    ...
# 195           37   East
# 196           33  South
# 197           42  North
# 198           44  South
# 199           24   East
#
# [200 rows x 2 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Filter rows where sales > 500.
df[df['sales'] > 500]
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 1        1002           29  North          Grocery   2241  2599      15.0
# 2        1003           15   West      Electronics   3159  1274       NaN
# 3        1004           43  South          Grocery   4648   978       5.0
# 4        1005            8  South        Furniture   3059  2086       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 195      1196           37   East         Clothing    639   932       0.0
# 196      1197           33  South      Electronics   2879  1080       0.0
# 197      1198           42  North      Electronics   4236  1076      15.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit
# 0    2024-01-01     3109    1113
# 1    2024-01-02     2164    -435
# 2    2024-01-03     3017    1743
# 3    2024-01-04     4519    3541
# 4    2024-01-05     3013     927
# ..          ...      ...     ...
# 195  2024-07-14      621    -311
# 196  2024-07-15     2830    1750
# 197  2024-07-16     4202    3126
# 198  2024-07-17     4823    3127
# 199  2024-07-18     3844    2876
#
# [194 rows x 10 columns]

# %%
# Add a new column profit = revenue - cost.
df['profit']=df['revenue']-df['cost']
df
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 1        1002           29  North          Grocery   2241  2599      15.0
# 2        1003           15   West      Electronics   3159  1274       NaN
# 3        1004           43  South          Grocery   4648   978       5.0
# 4        1005            8  South        Furniture   3059  2086       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 195      1196           37   East         Clothing    639   932       0.0
# 196      1197           33  South      Electronics   2879  1080       0.0
# 197      1198           42  North      Electronics   4236  1076      15.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit
# 0    2024-01-01     3109    1113
# 1    2024-01-02     2164    -435
# 2    2024-01-03     3017    1743
# 3    2024-01-04     4519    3541
# 4    2024-01-05     3013     927
# ..          ...      ...     ...
# 195  2024-07-14      621    -311
# 196  2024-07-15     2830    1750
# 197  2024-07-16     4202    3126
# 198  2024-07-17     4823    3127
# 199  2024-07-18     3844    2876
#
# [200 rows x 10 columns]

# %%
# Rename column cust_id to customer_id.
df.rename(columns={'customer_id':'cust_id'})
# Out:
#      order_id  cust_id region product_category  sales  cost  discount  \
# 0        1001       39  North      Electronics   3218  1996      10.0
# 1        1002       29  North          Grocery   2241  2599      15.0
# 2        1003       15   West      Electronics   3159  1274       NaN
# 3        1004       43  South          Grocery   4648   978       5.0
# 4        1005        8  South        Furniture   3059  2086       5.0
# ..        ...      ...    ...              ...    ...   ...       ...
# 195      1196       37   East         Clothing    639   932       0.0
# 196      1197       33  South      Electronics   2879  1080       0.0
# 197      1198       42  North      Electronics   4236  1076      15.0
# 198      1199       44  South         Clothing   4935  1696      10.0
# 199      1200       24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit
# 0    2024-01-01     3109    1113
# 1    2024-01-02     2164    -435
# 2    2024-01-03     3017    1743
# 3    2024-01-04     4519    3541
# 4    2024-01-05     3013     927
# ..          ...      ...     ...
# 195  2024-07-14      621    -311
# 196  2024-07-15     2830    1750
# 197  2024-07-16     4202    3126
# 198  2024-07-17     4823    3127
# 199  2024-07-18     3844    2876
#
# [200 rows x 10 columns]

# %%
# Drop column order_id.
df.drop('order_id',axis=1)
# Out:
#      customer_id region product_category  sales  cost  discount  order_date  \
# 0             39  North      Electronics   3218  1996      10.0  2024-01-01
# 1             29  North          Grocery   2241  2599      15.0  2024-01-02
# 2             15   West      Electronics   3159  1274       NaN  2024-01-03
# 3             43  South          Grocery   4648   978       5.0  2024-01-04
# 4              8  South        Furniture   3059  2086       5.0  2024-01-05
# ..           ...    ...              ...    ...   ...       ...         ...
# 195           37   East         Clothing    639   932       0.0  2024-07-14
# 196           33  South      Electronics   2879  1080       0.0  2024-07-15
# 197           42  North      Electronics   4236  1076      15.0  2024-07-16
# 198           44  South         Clothing   4935  1696      10.0  2024-07-17
# 199           24   East          Grocery   3875   968      15.0  2024-07-18
#
#      revenue  profit
# 0       3109    1113
# 1       2164    -435
# 2       3017    1743
# 3       4519    3541
# 4       3013     927
# ..       ...     ...
# 195      621    -311
# 196     2830    1750
# 197     4202    3126
# 198     4823    3127
# 199     3844    2876
#
# [200 rows x 9 columns]

# %%
# Sort dataset by sales descending.
df.sort_values(by='sales',ascending=False)
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 146      1147           15  North         Clothing   4949  1539      15.0
# 110      1111           35   West         Clothing   4946  2178      10.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 166      1167           32  South         Clothing   4880  2336       NaN
# 145      1146            9   East         Clothing   4848  1078       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 187      1188           13  North      Electronics    457   523      10.0
# 23       1024           21  North      Electronics    435  1065       0.0
# 94       1095           29   East        Furniture    243  2903       NaN
# 163      1164           29   West          Grocery    233  2144      10.0
# 53       1054           47   East        Furniture    214   763      15.0
#
#      order_date  revenue  profit
# 146  2024-05-26     4820    3281
# 110  2024-04-20     4805    2627
# 198  2024-07-17     4823    3127
# 166  2024-06-15     4683    2347
# 145  2024-05-25     4807    3729
# ..          ...      ...     ...
# 187  2024-07-06      367    -156
# 23   2024-01-24      316    -749
# 94   2024-04-04      185   -2718
# 163  2024-06-12       77   -2067
# 53   2024-02-23      188    -575
#
# [200 rows x 10 columns]

# %%
# Count number of non-null values in column sales.
len(df['sales'])        # total rows
df['sales'].count()     # non-null only
# Out:
# np.int64(200)

# %%
# Find unique values in column region.
df['region'].unique()
# Out:
# array(['North', 'West', 'South', 'East'], dtype=object)

# %%
# Convert column order_date to datetime.
df.rename(columns={'order_date':'datetime'})
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 1        1002           29  North          Grocery   2241  2599      15.0
# 2        1003           15   West      Electronics   3159  1274       NaN
# 3        1004           43  South          Grocery   4648   978       5.0
# 4        1005            8  South        Furniture   3059  2086       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 195      1196           37   East         Clothing    639   932       0.0
# 196      1197           33  South      Electronics   2879  1080       0.0
# 197      1198           42  North      Electronics   4236  1076      15.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#        datetime  revenue  profit
# 0    2024-01-01     3109    1113
# 1    2024-01-02     2164    -435
# 2    2024-01-03     3017    1743
# 3    2024-01-04     4519    3541
# 4    2024-01-05     3013     927
# ..          ...      ...     ...
# 195  2024-07-14      621    -311
# 196  2024-07-15     2830    1750
# 197  2024-07-16     4202    3126
# 198  2024-07-17     4823    3127
# 199  2024-07-18     3844    2876
#
# [200 rows x 10 columns]

# %%
# Find mean sales by each region.
df.groupby('region')['sales'].mean()
df
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 1        1002           29  North          Grocery   2241  2599      15.0
# 2        1003           15   West      Electronics   3159  1274       NaN
# 3        1004           43  South          Grocery   4648   978       5.0
# 4        1005            8  South        Furniture   3059  2086       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 195      1196           37   East         Clothing    639   932       0.0
# 196      1197           33  South      Electronics   2879  1080       0.0
# 197      1198           42  North      Electronics   4236  1076      15.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit
# 0    2024-01-01     3109    1113
# 1    2024-01-02     2164    -435
# 2    2024-01-03     3017    1743
# 3    2024-01-04     4519    3541
# 4    2024-01-05     3013     927
# ..          ...      ...     ...
# 195  2024-07-14      621    -311
# 196  2024-07-15     2830    1750
# 197  2024-07-16     4202    3126
# 198  2024-07-17     4823    3127
# 199  2024-07-18     3844    2876
#
# [200 rows x 10 columns]

# %%
# Find total revenue by product_category.
df.groupby('product_category')['revenue'].sum()
# Out:
# product_category
# Clothing       126479
# Electronics    138591
# Furniture       91023
# Grocery        146610
# Name: revenue, dtype: int64

# %%
# Find number of orders per customer.
df.groupby('customer_id')['order_id'].count()
# Out:
# customer_id
# 1      5
# 2      5
# 3      4
# 4      4
# 5      2
# 6      3
# 7      5
# 8      7
# 9      6
# 10     1
# 11     4
# 12     2
# 13     3
# 14     6
# 15     7
# 16     2
# 17     2
# 18     3
# 19     1
# 20     2
# 21     4
# 22     4
# 23     4
# 24     8
# 25     5
# 26     5
# 27     5
# 28     7
# 29     4
# 30     3
# 31     1
# 32     3
# 33     5
# 34     2
# 35     6
# 36     4
# 37     5
# 38     1
# 39     9
# 40     4
# 41     3
# 42     6
# 43     2
# 44    10
# 45     5
# 47     5
# 48     2
# 49     2
# 50     2
# Name: order_id, dtype: int64

# %%
# Find rows where region is either "East" or "West".
df[df['region'].isin(['East','West'])]
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 2        1003           15   West      Electronics   3159  1274       NaN
# 6        1007           39   East        Furniture   2579  2829      10.0
# 8        1009           23   East      Electronics   1735   974       NaN
# 9        1010           11   West          Grocery   1857  1631      15.0
# 10       1011           11   East      Electronics   4552   439       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 192      1193            8   West          Grocery   4285   575       5.0
# 193      1194           27   East        Furniture   3819  2796       NaN
# 194      1195            9   West      Electronics   2845  1385       5.0
# 195      1196           37   East         Clothing    639   932       0.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit
# 2    2024-01-03     3017    1743
# 6    2024-01-07     2443    -386
# 8    2024-01-09     1634     660
# 9    2024-01-10     1817     186
# 10   2024-01-11     4421    3982
# ..          ...      ...     ...
# 192  2024-07-11     4162    3587
# 193  2024-07-12     3695     899
# 194  2024-07-13     2822    1437
# 195  2024-07-14      621    -311
# 199  2024-07-18     3844    2876
#
# [89 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'region', 'product_category', 'sales',
#        'cost', 'discount', 'order_date', 'revenue', 'profit'],
#       dtype='object')

# %%
# Fill missing values in discount column with 0.
df['discount'] = df['discount'].fillna(0)
df
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 1        1002           29  North          Grocery   2241  2599      15.0
# 2        1003           15   West      Electronics   3159  1274       0.0
# 3        1004           43  South          Grocery   4648   978       5.0
# 4        1005            8  South        Furniture   3059  2086       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 195      1196           37   East         Clothing    639   932       0.0
# 196      1197           33  South      Electronics   2879  1080       0.0
# 197      1198           42  North      Electronics   4236  1076      15.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit
# 0    2024-01-01     3109    1113
# 1    2024-01-02     2164    -435
# 2    2024-01-03     3017    1743
# 3    2024-01-04     4519    3541
# 4    2024-01-05     3013     927
# ..          ...      ...     ...
# 195  2024-07-14      621    -311
# 196  2024-07-15     2830    1750
# 197  2024-07-16     4202    3126
# 198  2024-07-17     4823    3127
# 199  2024-07-18     3844    2876
#
# [200 rows x 10 columns]

# %%
# Drop rows containing any null values.
df.dropna(how='all')
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 1        1002           29  North          Grocery   2241  2599      15.0
# 2        1003           15   West      Electronics   3159  1274       0.0
# 3        1004           43  South          Grocery   4648   978       5.0
# 4        1005            8  South        Furniture   3059  2086       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 195      1196           37   East         Clothing    639   932       0.0
# 196      1197           33  South      Electronics   2879  1080       0.0
# 197      1198           42  North      Electronics   4236  1076      15.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit
# 0    2024-01-01     3109    1113
# 1    2024-01-02     2164    -435
# 2    2024-01-03     3017    1743
# 3    2024-01-04     4519    3541
# 4    2024-01-05     3013     927
# ..          ...      ...     ...
# 195  2024-07-14      621    -311
# 196  2024-07-15     2830    1750
# 197  2024-07-16     4202    3126
# 198  2024-07-17     4823    3127
# 199  2024-07-18     3844    2876
#
# [200 rows x 10 columns]

# %%
# Create a new column sales_tax = 10% of sales.
df['sales_tax']=df['sales']*0.10
df
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 1        1002           29  North          Grocery   2241  2599      15.0
# 2        1003           15   West      Electronics   3159  1274       0.0
# 3        1004           43  South          Grocery   4648   978       5.0
# 4        1005            8  South        Furniture   3059  2086       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 195      1196           37   East         Clothing    639   932       0.0
# 196      1197           33  South      Electronics   2879  1080       0.0
# 197      1198           42  North      Electronics   4236  1076      15.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit  sales_tax
# 0    2024-01-01     3109    1113      321.8
# 1    2024-01-02     2164    -435      224.1
# 2    2024-01-03     3017    1743      315.9
# 3    2024-01-04     4519    3541      464.8
# 4    2024-01-05     3013     927      305.9
# ..          ...      ...     ...        ...
# 195  2024-07-14      621    -311       63.9
# 196  2024-07-15     2830    1750      287.9
# 197  2024-07-16     4202    3126      423.6
# 198  2024-07-17     4823    3127      493.5
# 199  2024-07-18     3844    2876      387.5
#
# [200 rows x 11 columns]

# %%
# Sort by region ascending and sales descending.
df.sort_values(['region','sales'],ascending=[True,False])
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 145      1146            9   East         Clothing   4848  1078       5.0
# 106      1107           11   East        Furniture   4829  1408      10.0
# 20       1021           30   East      Electronics   4711   847      15.0
# 24       1025           33   East      Electronics   4692  1874       0.0
# 84       1085           21   East      Electronics   4592   673       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 151      1152           32   West        Furniture    994  2935      15.0
# 57       1058           47   West        Furniture    925  1951       0.0
# 129      1130           40   West        Furniture    610  2945       5.0
# 183      1184           39   West          Grocery    570   688      10.0
# 163      1164           29   West          Grocery    233  2144      10.0
#
#      order_date  revenue  profit  sales_tax
# 145  2024-05-25     4807    3729      484.8
# 106  2024-04-16     4706    3298      482.9
# 20   2024-01-21     4601    3754      471.1
# 24   2024-01-25     4519    2645      469.2
# 84   2024-03-25     4512    3839      459.2
# ..          ...      ...     ...        ...
# 151  2024-05-31      843   -2092       99.4
# 57   2024-02-27      808   -1143       92.5
# 129  2024-05-09      536   -2409       61.0
# 183  2024-07-02      462    -226       57.0
# 163  2024-06-12       77   -2067       23.3
#
# [200 rows x 11 columns]

# %%
# Reset DataFrame index.
df.reset_index()
# Out:
#      index  order_id  customer_id region product_category  sales  cost  \
# 0        0      1001           39  North      Electronics   3218  1996
# 1        1      1002           29  North          Grocery   2241  2599
# 2        2      1003           15   West      Electronics   3159  1274
# 3        3      1004           43  South          Grocery   4648   978
# 4        4      1005            8  South        Furniture   3059  2086
# ..     ...       ...          ...    ...              ...    ...   ...
# 195    195      1196           37   East         Clothing    639   932
# 196    196      1197           33  South      Electronics   2879  1080
# 197    197      1198           42  North      Electronics   4236  1076
# 198    198      1199           44  South         Clothing   4935  1696
# 199    199      1200           24   East          Grocery   3875   968
#
#      discount  order_date  revenue  profit  sales_tax
# 0        10.0  2024-01-01     3109    1113      321.8
# 1        15.0  2024-01-02     2164    -435      224.1
# 2         0.0  2024-01-03     3017    1743      315.9
# 3         5.0  2024-01-04     4519    3541      464.8
# 4         5.0  2024-01-05     3013     927      305.9
# ..        ...         ...      ...     ...        ...
# 195       0.0  2024-07-14      621    -311       63.9
# 196       0.0  2024-07-15     2830    1750      287.9
# 197      15.0  2024-07-16     4202    3126      423.6
# 198      10.0  2024-07-17     4823    3127      493.5
# 199      15.0  2024-07-18     3844    2876      387.5
#
# [200 rows x 12 columns]

# %%
# Set order_id as index.
df.set_index('order_id')
# Out:
#           customer_id region product_category  sales  cost  discount  \
# order_id
# 1001               39  North      Electronics   3218  1996      10.0
# 1002               29  North          Grocery   2241  2599      15.0
# 1003               15   West      Electronics   3159  1274       0.0
# 1004               43  South          Grocery   4648   978       5.0
# 1005                8  South        Furniture   3059  2086       5.0
# ...               ...    ...              ...    ...   ...       ...
# 1196               37   East         Clothing    639   932       0.0
# 1197               33  South      Electronics   2879  1080       0.0
# 1198               42  North      Electronics   4236  1076      15.0
# 1199               44  South         Clothing   4935  1696      10.0
# 1200               24   East          Grocery   3875   968      15.0
#
#           order_date  revenue  profit  sales_tax
# order_id
# 1001      2024-01-01     3109    1113      321.8
# 1002      2024-01-02     2164    -435      224.1
# 1003      2024-01-03     3017    1743      315.9
# 1004      2024-01-04     4519    3541      464.8
# 1005      2024-01-05     3013     927      305.9
# ...              ...      ...     ...        ...
# 1196      2024-07-14      621    -311       63.9
# 1197      2024-07-15     2830    1750      287.9
# 1198      2024-07-16     4202    3126      423.6
# 1199      2024-07-17     4823    3127      493.5
# 1200      2024-07-18     3844    2876      387.5
#
# [200 rows x 10 columns]

# %%
# Get top 5 rows with highest sales.
df.nlargest(5, 'sales')
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 146      1147           15  North         Clothing   4949  1539      15.0
# 110      1111           35   West         Clothing   4946  2178      10.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 166      1167           32  South         Clothing   4880  2336       0.0
# 145      1146            9   East         Clothing   4848  1078       5.0
#
#      order_date  revenue  profit  sales_tax
# 146  2024-05-26     4820    3281      494.9
# 110  2024-04-20     4805    2627      494.6
# 198  2024-07-17     4823    3127      493.5
# 166  2024-06-15     4683    2347      488.0
# 145  2024-05-25     4807    3729      484.8

# %%
df.sort_values('sales', ascending=False).head(5)
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 146      1147           15  North         Clothing   4949  1539      15.0
# 110      1111           35   West         Clothing   4946  2178      10.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 166      1167           32  South         Clothing   4880  2336       0.0
# 145      1146            9   East         Clothing   4848  1078       5.0
#
#      order_date  revenue  profit  sales_tax
# 146  2024-05-26     4820    3281      494.9
# 110  2024-04-20     4805    2627      494.6
# 198  2024-07-17     4823    3127      493.5
# 166  2024-06-15     4683    2347      488.0
# 145  2024-05-25     4807    3729      484.8

# %%
# Create a pivot table showing total sales by region and category.
pd.pivot_table(
    df,
    values='sales',
    index='region',
    columns='product_category',
    aggfunc='sum'
)
# Out:
# product_category  Clothing  Electronics  Furniture  Grocery
# region
# East                 26234        44534      23027    22692
# North                34763        34705      15308    44238
# South                45407        35510      23419    54003
# West                 25695        29526      33652    31230

# %%
# duplicate rows in dataset Find .
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
# Remove duplicate rows.
df.drop_duplicates()
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 1        1002           29  North          Grocery   2241  2599      15.0
# 2        1003           15   West      Electronics   3159  1274       0.0
# 3        1004           43  South          Grocery   4648   978       5.0
# 4        1005            8  South        Furniture   3059  2086       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 195      1196           37   East         Clothing    639   932       0.0
# 196      1197           33  South      Electronics   2879  1080       0.0
# 197      1198           42  North      Electronics   4236  1076      15.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit  sales_tax
# 0    2024-01-01     3109    1113      321.8
# 1    2024-01-02     2164    -435      224.1
# 2    2024-01-03     3017    1743      315.9
# 3    2024-01-04     4519    3541      464.8
# 4    2024-01-05     3013     927      305.9
# ..          ...      ...     ...        ...
# 195  2024-07-14      621    -311       63.9
# 196  2024-07-15     2830    1750      287.9
# 197  2024-07-16     4202    3126      423.6
# 198  2024-07-17     4823    3127      493.5
# 199  2024-07-18     3844    2876      387.5
#
# [200 rows x 11 columns]

# %%
# Merge df_orders and df_customers on customer_id.
import pandas as pd

merged_df = pd.merge(df1, df2,on='customer_id')
merged_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       1 # Merge df_orders and df_customers on customer_id.
#       2 import pandas as pd
# ----> 4 merged_df = pd.merge(df1, df2,on='customer_id')
#       5 merged_df
#
# NameError: name 'df1' is not defined

# %%
# Concatenate two DataFrames vertically.
import pandas as pd

result = pd.concat([df1, df2])
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       1 # Concatenate two DataFrames vertically.
#       2 import pandas as pd
# ----> 4 result = pd.concat([df1, df2])
#       5 result
#
# NameError: name 'df1' is not defined

# %%
# Create a new column year extracted from order_date.
df['year']=df['order_date'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 2
#       1 # Create a new column year extracted from order_date.
# ----> 2 df['year']=df['order_date'].dt.year
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\accessors.py:643, in CombinedDatetimelikeProperties.__new__(cls, data)
#     640 elif isinstance(data.dtype, PeriodDtype):
#     641     return PeriodProperties(data, orig)
# --> 643 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
df['order_date'] = pd.to_datetime(df['order_date']).dt.year
df
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 1        1002           29  North          Grocery   2241  2599      15.0
# 2        1003           15   West      Electronics   3159  1274       0.0
# 3        1004           43  South          Grocery   4648   978       5.0
# 4        1005            8  South        Furniture   3059  2086       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 195      1196           37   East         Clothing    639   932       0.0
# 196      1197           33  South      Electronics   2879  1080       0.0
# 197      1198           42  North      Electronics   4236  1076      15.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit  sales_tax
# 0          2024     3109    1113      321.8
# 1          2024     2164    -435      224.1
# 2          2024     3017    1743      315.9
# 3          2024     4519    3541      464.8
# 4          2024     3013     927      305.9
# ..          ...      ...     ...        ...
# 195        2024      621    -311       63.9
# 196        2024     2830    1750      287.9
# 197        2024     4202    3126      423.6
# 198        2024     4823    3127      493.5
# 199        2024     3844    2876      387.5
#
# [200 rows x 11 columns]

# %%
# Calculate cumulative sales by date.
df['date']=pd.to_datetime(df['order_date']).dt.date
df=df.sort_values('date')
df['cumulative_sales']=df['sales'].cumsum()
df
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 127      1128           35  South          Grocery    599  2208       0.0
# 128      1129           44  South      Electronics   1780   810       0.0
# 129      1130           40   West        Furniture    610  2945       5.0
# 130      1131           22  South          Grocery   4412  2192       0.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 70       1071           18  South      Electronics   4179  2251      15.0
# 71       1072           26  South         Clothing   1671   299       0.0
# 72       1073           44  North        Furniture   2243   723      15.0
# 62       1063           50   East      Electronics   3448  1519       5.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit  sales_tax        date  cumulative_sales
# 0          2024     3109    1113      321.8  1970-01-01              3218
# 127        2024      497   -1711       59.9  1970-01-01              3817
# 128        2024     1763     953      178.0  1970-01-01              5597
# 129        2024      536   -2409       61.0  1970-01-01              6207
# 130        2024     4346    2154      441.2  1970-01-01             10619
# ..          ...      ...     ...        ...         ...               ...
# 70         2024     4014    1763      417.9  1970-01-01            512706
# 71         2024     1548    1249      167.1  1970-01-01            514377
# 72         2024     2185    1462      224.3  1970-01-01            516620
# 62         2024     3259    1740      344.8  1970-01-01            520068
# 199        2024     3844    2876      387.5  1970-01-01            523943
#
# [200 rows x 13 columns]

# %%
# Find correlation between sales and profit.
df[['sales', 'profit']].corr()
# Out:
#            sales    profit
# sales   1.000000  0.828093
# profit  0.828093  1.000000

# %%
# Find covariance between numeric columns.
df[['sales', 'profit']].cov()
# Out:
#                sales        profit
# sales   1.714638e+06  1.754019e+06
# profit  1.754019e+06  2.616604e+06

# %%
# Get row that contains maximum sales.
df.sort_values('sales', ascending=False).head(1)  #slower
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 146      1147           15  North         Clothing   4949  1539      15.0
#
#      order_date  revenue  profit  sales_tax        date  cumulative_sales
# 146        2024     4820    3281      494.9  1970-01-01             60121

# %%
df.loc[df['sales'].idxmax()]    # faster
# Out:
# order_id                  1147
# customer_id                 15
# region                   North
# product_category      Clothing
# sales                     4949
# cost                      1539
# discount                  15.0
# order_date                2024
# revenue                   4820
# profit                    3281
# sales_tax                494.9
# date                1970-01-01
# cumulative_sales         60121
# Name: 146, dtype: object

# %%
# Get row that contains minimum profit.
df.sort_values('profit',ascending=True).head(1)
# Out:
#     order_id  customer_id region product_category  sales  cost  discount  \
# 94      1095           29   East        Furniture    243  2903       0.0
#
#     order_date  revenue  profit  sales_tax        date  cumulative_sales
# 94        2024      185   -2718       24.3  1970-01-01            443002

# %%
df.loc[df['profit'].idxmin()]
# Out:
# order_id                  1095
# customer_id                 29
# region                    East
# product_category     Furniture
# sales                      243
# cost                      2903
# discount                   0.0
# order_date                2024
# revenue                    185
# profit                   -2718
# sales_tax                 24.3
# date                1970-01-01
# cumulative_sales        443002
# Name: 94, dtype: object

# %%
# Apply lambda function to label sales as "High" if >1000 else "Low".
df['sales_label'] = df['sales'].apply(
    lambda x: 'High' if x > 1000 else 'Low'
)
df
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 127      1128           35  South          Grocery    599  2208       0.0
# 128      1129           44  South      Electronics   1780   810       0.0
# 129      1130           40   West        Furniture    610  2945       5.0
# 130      1131           22  South          Grocery   4412  2192       0.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 70       1071           18  South      Electronics   4179  2251      15.0
# 71       1072           26  South         Clothing   1671   299       0.0
# 72       1073           44  North        Furniture   2243   723      15.0
# 62       1063           50   East      Electronics   3448  1519       5.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit  sales_tax        date  cumulative_sales  \
# 0          2024     3109    1113      321.8  1970-01-01              3218
# 127        2024      497   -1711       59.9  1970-01-01              3817
# 128        2024     1763     953      178.0  1970-01-01              5597
# 129        2024      536   -2409       61.0  1970-01-01              6207
# 130        2024     4346    2154      441.2  1970-01-01             10619
# ..          ...      ...     ...        ...         ...               ...
# 70         2024     4014    1763      417.9  1970-01-01            512706
# 71         2024     1548    1249      167.1  1970-01-01            514377
# 72         2024     2185    1462      224.3  1970-01-01            516620
# 62         2024     3259    1740      344.8  1970-01-01            520068
# 199        2024     3844    2876      387.5  1970-01-01            523943
#
#     sales_label
# 0          High
# 127         Low
# 128        High
# 129         Low
# 130        High
# ..          ...
# 70         High
# 71         High
# 72         High
# 62         High
# 199        High
#
# [200 rows x 14 columns]

# %%
# Calculate rolling 7-day average of sales.
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values('date')
df['rolling_7day_avg_sales'] = df['sales'].rolling(window=7).mean()
df
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 129      1130           40   West        Furniture    610  2945       5.0
# 130      1131           22  South          Grocery   4412  2192       0.0
# 131      1132           27   East         Clothing   1424  2044       5.0
# 132      1133           35  South      Electronics   1255  1985      10.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 72       1073           44  North        Furniture   2243   723      15.0
# 51       1052           20   West         Clothing   3169  1510      15.0
# 52       1053           28  South          Grocery    517  2774       5.0
# 64       1065            4  South      Electronics    775   930       0.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit  sales_tax       date  cumulative_sales  \
# 0          2024     3109    1113      321.8 1970-01-01              3218
# 129        2024      536   -2409       61.0 1970-01-01              6207
# 130        2024     4346    2154      441.2 1970-01-01             10619
# 131        2024     1348    -696      142.4 1970-01-01             12043
# 132        2024     1059    -926      125.5 1970-01-01             13298
# ..          ...      ...     ...        ...        ...               ...
# 72         2024     2185    1462      224.3 1970-01-01            516620
# 51         2024     2998    1488      316.9 1970-01-01            470550
# 52         2024      417   -2357       51.7 1970-01-01            471067
# 64         2024      605    -325       77.5 1970-01-01            495183
# 199        2024     3844    2876      387.5 1970-01-01            523943
#
#     sales_label  rolling_7day_avg_sales
# 0          High                     NaN
# 129         Low                     NaN
# 130        High                     NaN
# 131        High                     NaN
# 132        High                     NaN
# ..          ...                     ...
# 72         High             2553.142857
# 51         High             2633.857143
# 52          Low             2269.571429
# 64          Low             1968.000000
# 199        High             2347.000000
#
# [200 rows x 15 columns]

# %%
# Create bar chart of total sales by region.
import pandas as pd
import matplotlib.pyplot as plt

# Sample example data (replace with your actual DataFrame)
df = pd.DataFrame({
    'region': ['East', 'West', 'East', 'North', 'West', 'North'],
    'sales': [500, 700, 300, 400, 600, 800]
})

# Calculate total sales by region
region_sales = df.groupby('region')['sales'].sum()

# Create bar chart
plt.figure()
plt.bar(region_sales.index, region_sales.values)
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region')
plt.show()

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\rrama\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\rrama\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rrama\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\rrama\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------------------------ --------------- 5.0/8.1 MB 30.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 36.0 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 43.8 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Downloading pillow-12.1.0-cp312-cp312-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 7.0/7.0 MB 48.4 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.0 pyparsing-3.3.2
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Create bar chart of total sales by region.
df=pd.read_csv(r"C:\Users\rrama\OneDrive\Desktop\Python code\pandas_practice_dataset.csv")
region_sales = df.groupby('region')['sales'].sum()
plt.figure()
plt.bar(region_sales.index, region_sales.values)
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region')
plt.show()

# %%
# Randomly sample 10 rows.
df.sample(10)
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 118      1119            9  North         Clothing   2781  1925      15.0
# 38       1039           37  South          Grocery   4480  1683      10.0
# 122      1123           33  North      Electronics   2486  1523       NaN
# 92       1093           45  South          Grocery   2882   813      15.0
# 187      1188           13  North      Electronics    457   523      10.0
# 138      1139            3   West        Furniture   2314  1937       0.0
# 71       1072           26  South         Clothing   1671   299       0.0
# 35       1036           47   West          Grocery   3598  2892       5.0
# 17       1018            2  North         Clothing   2916  2547       NaN
# 15       1016            3  North         Clothing   2589  1888       0.0
#
#      order_date  revenue  profit
# 118  2024-04-28     2762     837
# 38   2024-02-08     4291    2608
# 122  2024-05-02     2390     867
# 92   2024-04-02     2715    1902
# 187  2024-07-06      367    -156
# 138  2024-05-18     2213     276
# 71   2024-03-12     1548    1249
# 35   2024-02-05     3414     522
# 17   2024-01-18     2756     209
# 15   2024-01-16     2539     651
